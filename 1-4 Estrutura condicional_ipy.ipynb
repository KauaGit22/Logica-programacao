# %% [markdown]
# Calculadora

# %%
expressão_matematica = input('digite uma expressão matematica:')

resultado = eval(expressão_matematica)

print('O resultado é', resultado )
# Out:
# digite uma expressão matematica:2 + 20 + 65 + 80
# O resultado é 167
